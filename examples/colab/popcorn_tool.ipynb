# %% [markdown]
# <a href="https://colab.research.google.com/github/RecSys-lab/Popcorn/blob/main/examples/colab/popcorn_tool.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **🍿 Popcorn Framework**
# ### **From Data Feed to Recommender List Generation**
#
# 🎬 Popcorn Framework: [link](https://github.com/RecSys-lab/Popcorn)

# %% [markdown]
# ## **[Step 1] Clone Popcorn Movie Recommender Tool**
#
# Clone the framework into your `GDrive` and prepare it for experiments.
#
# ⚠️ You might see a *"Restart Session"* warning during the first run in Google Colab due to library version mismatches. This is expected! Accept the restart, re-run this cell, and continue!

# %%
# Clone the repo
# !git clone https://github.com/RecSys-lab/Popcorn.git

# Install the required library
# %cd Popcorn
# !pip install -e .

# Add the repository to the Python path
import sys
sys.path.append('/content/Popcorn')

# Go back to the root
# %cd ..
# Out:
# fatal: destination path 'Popcorn' already exists and is not an empty directory.
# /content/Popcorn
# Obtaining file:///content/Popcorn
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: setuptools==80.9.0 in /usr/local/lib/python3.12/dist-packages (from Popcorn==1.6.0) (80.9.0)
# Requirement already satisfied: PyYAML==6.0.2 in /usr/local/lib/python3.12/dist-packages (from Popcorn==1.6.0) (6.0.2)
# Requirement already satisfied: requests==2.32.5 in /usr/local/lib/python3.12/dist-packages (from Popcorn==1.6.0) (2.32.5)
# Requirement already satisfied: pandas==2.3.0 in /usr/local/lib/python3.12/dist-packages (from Popcorn==1.6.0) (2.3.0)
# Requirement already satisfied: numpy==2.3.2 in /usr/local/lib/python3.12/dist-packages (from Popcorn==1.6.0) (2.3.2)
# Requirement already satisfied: scikit-learn==1.7.2 in /usr/local/lib/python3.12/dist-packages (from Popcorn==1.6.0) (1.7.2)
# Requirement already satisfied: yt-dlp==2025.9.26 in /usr/local/lib/python3.12/dist-packages (from Popcorn==1.6.0) (2025.9.26)
# Requirement already satisfied: opencv-python==4.11.0.86 in /usr/local/lib/python3.12/dist-packages (from Popcorn==1.6.0) (4.11.0.86)
# Requirement already satisfied: keras==3.11.3 in /usr/local/lib/python3.12/dist-packages (from Popcorn==1.6.0) (3.11.3)
# Requirement already satisfied: torch==2.8.0 in /usr/local/lib/python3.12/dist-packages (from Popcorn==1.6.0) (2.8.0)
# Requirement already satisfied: cornac==2.3.3 in /usr/local/lib/python3.12/dist-packages (from Popcorn==1.6.0) (2.3.3)
# Requirement already satisfied: openai==2.16.0 in /usr/local/lib/python3.12/dist-packages (from Popcorn==1.6.0) (2.16.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from cornac==2.3.3->Popcorn==1.6.0) (1.16.3)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from cornac==2.3.3->Popcorn==1.6.0) (4.67.2)
# Requirement already satisfied: powerlaw in /usr/local/lib/python3.12/dist-packages (from cornac==2.3.3->Popcorn==1.6.0) (2.0.0)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.12/dist-packages (from keras==3.11.3->Popcorn==1.6.0) (1.4.0)
# Requirement already satisfied: rich in /usr/local/lib/python3.12/dist-packages (from keras==3.11.3->Popcorn==1.6.0) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.12/dist-packages (from keras==3.11.3->Popcorn==1.6.0) (0.1.0)
# Requirement already satisfied: h5py in /usr/local/lib/python3.12/dist-packages (from keras==3.11.3->Popcorn==1.6.0) (3.15.1)
# Requirement already satisfied: optree in /usr/local/lib/python3.12/dist-packages (from keras==3.11.3->Popcorn==1.6.0) (0.18.0)
# Requirement already satisfied: ml-dtypes in /usr/local/lib/python3.12/dist-packages (from keras==3.11.3->Popcorn==1.6.0) (0.5.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from keras==3.11.3->Popcorn==1.6.0) (26.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from openai==2.16.0->Popcorn==1.6.0) (4.12.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai==2.16.0->Popcorn==1.6.0) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from openai==2.16.0->Popcorn==1.6.0) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.10.0 in /usr/local/lib/python3.12/dist-packages (from openai==2.16.0->Popcorn==1.6.0) (0.13.0)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from openai==2.16.0->Popcorn==1.6.0) (2.12.3)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai==2.16.0->Popcorn==1.6.0) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.11 in /usr/local/lib/python3.12/dist-packages (from openai==2.16.0->Popcorn==1.6.0) (4.15.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas==2.3.0->Popcorn==1.6.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas==2.3.0->Popcorn==1.6.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas==2.3.0->Popcorn==1.6.0) (2025.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests==2.32.5->Popcorn==1.6.0) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests==2.32.5->Popcorn==1.6.0) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests==2.32.5->Popcorn==1.6.0) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests==2.32.5->Popcorn==1.6.0) (2026.1.4)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn==1.7.2->Popcorn==1.6.0) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn==1.7.2->Popcorn==1.6.0) (3.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->Popcorn==1.6.0) (3.20.3)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->Popcorn==1.6.0) (1.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->Popcorn==1.6.0) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->Popcorn==1.6.0) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->Popcorn==1.6.0) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->Popcorn==1.6.0) (12.8.93)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->Popcorn==1.6.0) (12.8.90)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->Popcorn==1.6.0) (12.8.90)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->Popcorn==1.6.0) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.8.4.1 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->Popcorn==1.6.0) (12.8.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.3.83 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->Popcorn==1.6.0) (11.3.3.83)
# Requirement already satisfied: nvidia-curand-cu12==10.3.9.90 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->Popcorn==1.6.0) (10.3.9.90)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.3.90 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->Popcorn==1.6.0) (11.7.3.90)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.8.93 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->Popcorn==1.6.0) (12.5.8.93)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->Popcorn==1.6.0) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.3 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->Popcorn==1.6.0) (2.27.3)
# Requirement already satisfied: nvidia-nvtx-cu12==12.8.90 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->Popcorn==1.6.0) (12.8.90)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.8.93 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->Popcorn==1.6.0) (12.8.93)
# Requirement already satisfied: nvidia-cufile-cu12==1.13.1.3 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->Popcorn==1.6.0) (1.13.1.3)
# Requirement already satisfied: triton==3.4.0 in /usr/local/lib/python3.12/dist-packages (from torch==2.8.0->Popcorn==1.6.0) (3.4.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai==2.16.0->Popcorn==1.6.0) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai==2.16.0->Popcorn==1.6.0) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openai==2.16.0->Popcorn==1.6.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openai==2.16.0->Popcorn==1.6.0) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->openai==2.16.0->Popcorn==1.6.0) (0.4.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas==2.3.0->Popcorn==1.6.0) (1.17.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch==2.8.0->Popcorn==1.6.0) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch==2.8.0->Popcorn==1.6.0) (3.0.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from powerlaw->cornac==2.3.3->Popcorn==1.6.0) (3.10.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras==3.11.3->Popcorn==1.6.0) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich->keras==3.11.3->Popcorn==1.6.0) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich->keras==3.11.3->Popcorn==1.6.0) (0.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->powerlaw->cornac==2.3.3->Popcorn==1.6.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->powerlaw->cornac==2.3.3->Popcorn==1.6.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->powerlaw->cornac==2.3.3->Popcorn==1.6.0) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->powerlaw->cornac==2.3.3->Popcorn==1.6.0) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->powerlaw->cornac==2.3.3->Popcorn==1.6.0) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->powerlaw->cornac==2.3.3->Popcorn==1.6.0) (3.3.2)
# Installing collected packages: Popcorn
#   Attempting uninstall: Popcorn
#     Found existing installation: Popcorn 1.6.0
#     Uninstalling Popcorn-1.6.0:
#       Successfully uninstalled Popcorn-1.6.0
#   Running setup.py develop for Popcorn
# Successfully installed Popcorn-1.6.0
# /content

# %% [markdown]
# ## 🚀 **[Step 2] Use the Framework**

# %% [markdown]
# ### *1. Load Configurations and Imports*

# %%
import os
import json
import pandas as pd
from popcorn.utils import readConfigs

# Start the Framework
print("Welcome to 'Popcorn' 🍿! Starting the framework for your movie recommendation ...\n")

# Read the configuration file
configs = readConfigs("Popcorn/popcorn/config/config.yml")
# If properly read, print the configurations
if not configs:
    print("Error reading the configuration file!")
# Out:
# Welcome to 'Popcorn' 🍿! Starting the framework for your movie recommendation ...
#
# - Reading the framework's configuration file ...
# - Configuration file loaded successfully!

# %%
# @title ⚙️ Configurations
# @markdown ⚙️ Choose your desired configurations:

textual_modality = "OpenAI (raw)"  # @param ['None', 'OpenAI (raw)', 'OpenAI (augmented)', 'Llama (raw)', 'Llama (augmented)', 'ST (raw)', 'ST (augmented)']
audio_modality = "None"  # @param ['None', 'MMTF (i-vec)', 'MMTF (BLF)']
visual_modality = "Popcorn (Trailer - VGG19)"  # @param ['None', 'MMTF (CNN)', 'MMTF (AVF)', 'Popcorn (Trailer - VGG19)', 'Popcorn (Trailer - Incp3)', 'Popcorn (Full-Movie - VGG19)', 'Popcorn (Full-Movie - Incp3)', 'Popcorn (Shot - VGG19)', 'Popcorn (Shot - Incp3)']
movielens = "1m"  # @param ['100k', '1m', '25m']
split_method = 'random' # @param ['random', 'temporal', 'per_user']
recom_model = 'vbpr' # @param ['cf', 'vbpr', 'amr', 'vmf']
fusion_methods = 'CCA + PCA' # @param ['CCA', 'PCA', 'CCA + PCA']
cca_components = 40 # @param {"type":"slider","min":4,"max":64,"step":4}
pca_components = 0.8 # @param {"type":"slider","min":0.4,"max":0.99,"step":0.01}
top_n = 2 # @param ["2","5","10","15","20","25","30","50"] {"type":"raw"}
test_ratio = 0.2 # @param {"type":"slider","min":0.1,"max":0.9,"step":0.1}
n_epochs = 1 # @param {"type":"slider","min":1,"max":50,"step":1}

# %%
# Override Configurations

# MovieLens Dataset
configs["datasets"]["unimodal"]["movielens"]["version"] = movielens
configs["datasets"]["unimodal"]["movielens"]["download_path"] = "/content/MovieLens"

# Poison-RAG-Plus Dataset (LLM-Augmented Text)
configs["datasets"]["unimodal"]["poison_rag_plus"]["augmented"] = True if textual_modality.find("(augmented)") != -1 else False
configs["datasets"]["unimodal"]["poison_rag_plus"]["llm"] = "openai" if textual_modality.find("OpenAI") != -1 else "st" if textual_modality.find("ST") != -1 else "llama" # 'openai' | 'st' | 'llama'

# Popcorn-Visual Dataset (Full-Movies)
configs["datasets"]["multimodal"]["popcorn"]["cnns"] = ["incp3"] if visual_modality.find("Incp3") != -1 else ["vgg19"] # 'incp3' | 'vgg19'
configs["datasets"]["multimodal"]["popcorn"]["agg_embedding_sources"] = ["movie_trailers_agg"] if visual_modality.find("Trailer") != -1 else ["full_movies_agg"] if visual_modality.find("Full-Movie") != -1 else ["movie_shots_agg"] # 'full_movies_agg' | 'movie_shots_agg' | 'movie_trailers_agg'

# MMTF-14K Dataset (Full-Movies)
configs["datasets"]["multimodal"]["mmtf"]["visual_variant"] = "cnn" if visual_modality.find("(CNN)") != -1 else "avf" # 'avf' | 'cnn'
configs["datasets"]["multimodal"]["mmtf"]["audio_variant"] = "ivec" if audio_modality.find("i-vec") != -1 else "blf" # 'blf' | 'ivec'
configs["datasets"]["multimodal"]["mmtf"]["audio_blf_pca"] = 0.95

# Modalities
# [Supported]: 'audio_mmtf' | 'visual_mmtf' | 'text_rag_plus' | 'visual_popcorn'
configs["modalities"]['selected'] = []
if textual_modality != "None":
  configs["modalities"]['selected'].append("text_rag_plus")
if audio_modality != "None":
  configs["modalities"]['selected'].append("audio_mmtf")
if visual_modality != "None":
  if visual_modality.find("MMTF") != -1:
    configs["modalities"]['selected'].append("visual_mmtf")
  else:
    configs["modalities"]['selected'].append("visual_popcorn")

configs["modalities"]["fusion_methods"]['selected'] = ["concat"] # 'concat' | 'cca' | 'pca'
if fusion_methods.find("CCA") != -1:
  configs["modalities"]["fusion_methods"]['selected'].append("cca")
if fusion_methods.find("PCA") != -1:
  configs["modalities"]["fusion_methods"]['selected'].append("pca")

configs["modalities"]["fusion_methods"]['cca_components'] = cca_components
configs["modalities"]["fusion_methods"]['pca_variance'] = pca_components
configs["modalities"]["fusion_methods"]['cca_reg'] = 0.01 # CCA Lambda, can be modified
configs["modalities"]["fusion_methods"]['pca_reg'] = 0.01 # PCA Lambda, can be modified

# Setup
configs["setup"]['k_core'] = 10 # K-Core Filter, can be modified
configs["setup"]["n_epochs"] = n_epochs
configs["setup"]["use_gpu"] = False # Recommended to keep it False in Google Colab, due to torch conflicts
configs["setup"]["use_parallel"] = True
configs["setup"]["is_fast_prototype"] = True if n_epochs == 1 else False
configs["setup"]['split']['mode'] = split_method # 'random' | 'temporal' | 'per_user'
configs["setup"]['split']['test_ratio'] = test_ratio

# Recommendation
configs["setup"]["model_choice"] = recom_model # 'cf' | 'vbpr' | 'amr' | 'vmf'
configs["recommender"]["top_n"] = top_n # 2 | 5 | 10 | 15 | 20 | 25 | 30 | 50

# %% [markdown]
# ### *2. The Rest of the Procedures*

# %%
from popcorn.recommenders.reclist import generateLists
from popcorn.optimizers.grid_search import gridSearch
from popcorn.recommenders.assembler import assembleModality

# Clear output path
cca = str(configs["modalities"]["fusion_methods"]['cca_components'])
lmbp = str(configs["modalities"]["fusion_methods"]['pca_reg']).replace(".", "")
lmbc = str(configs["modalities"]["fusion_methods"]['cca_reg']).replace(".", "")
pca = str(configs["modalities"]["fusion_methods"]['pca_variance']).replace(".", "")
configs["general"]["output_path"] = f"output_pca{pca}_plmb{lmbp}_cca{cca}_clmb{lmbc}"

# -------------------------------------------------
# Assemble Modalities and Get Train/Test/Modalities
# ------------------------------------------------
trainDF, testDF, trainSet, modalitiesDict, genreDict = assembleModality(configs)
print("- Modalities assembled successfully!")
print(f"- Training set size: {trainDF.shape}, Testing set size: {testDF.shape}")
print(f"- Available modalities: {list(modalitiesDict.keys())}")

# -----------------------------------
# Apply GridSearch and Get Parameters
# -----------------------------------
finalModels = gridSearch(configs, trainDF, trainSet, modalitiesDict)
print("\n✔ Grid search completed successfully!")
print(f"- Final models after HPO: {list(finalModels.keys())}")

# -----------------------------
# Generate Recommendation Lists
# -----------------------------
generateLists(configs, trainDF, trainSet, testDF, genreDict, finalModels)
# Out:
# - Downloading the MovieLens-1m dataset ...
# - Creating the download path '/content/MovieLens/ml-1m' ...
# - Fetching data from 'https://files.grouplens.org/datasets/movielens/ml-1m.zip' ...
# - Download completed and the dataset is saved as a 'zip' file!
# - Extracting the dataset files inside '/content/MovieLens/ml-1m' ...
# - Dataset extracted to '/content/MovieLens/ml-1m' successfully!
# - Removing the zip file '/content/MovieLens/ml-1m/ml-1m.zip' ...
# - Zip file removed successfully!
#
# - Loading 'MovieLens-1m' data from '/content/MovieLens/ml-1m/ml-1m' ...
# - Items (movies) have been loaded. Number of rows: 3,883
# - Users have been loaded. Number of rows: 6,040
# - Ratings have been loaded. Number of rows: 1,000,209
#
# - Preparing to save the genres DataFrame in 'output_pca08_plmb001_cca40_clmb001' ...
# - Genres DataFrame saved to 'output_pca08_plmb001_cca40_clmb001/item_genre_ml-1m.csv'!
# - Genre dictionary loaded:
# {'1': ['Animation', "Children's", 'Comedy'], '2': ['Adventure', "Children's", 'Fantasy'], '3': ['Comedy', 'Romance']}
# - Applying 10-core filtering ...
# - After 10-core filtering row count: 998,539
#
# - Splitting the ratings DataFrame using 'random' mode and test ratio '0.2' ...
# - Splitting finished! Train data: 798,832 - Test data: 199,707.
#
# - Preparing the 'Poison-RAG-Plus' dataset with 'openai'-driven original embeddings ...
# -- Loading data from 'openai_originalraw_combined_all_part1.csv.gz' ...
# -- Loading data from 'openai_originalraw_combined_all_part2.csv.gz' ...
# -- Loading data from 'openai_originalraw_combined_all_part3.csv.gz' ...
# -- Loading data from 'openai_originalraw_combined_all_part4.csv.gz' ...
# - Finished loading 3 parts of textual original data with 1,606 items!
# - Fetching URL from 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/resolve/main/stats.json' ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/resolve/main/stats.json' ...
# - JSON data loaded successfully!
# - Fetching all movie IDs ...
# - Generating a list of addresses to fetch the aggregated features of all movies (CNNs: ['vgg19'], Embeddings: ['movie_trailers_agg']) ...
# - Generated 274 aggregated feature addresses, e.g., https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000000006.json ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000000006.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000000050.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (0%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000000111.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000000150.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (1%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000000165.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000000231.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (2%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000000266.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000000293.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (2%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000000296.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000000318.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (3%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000000356.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000000420.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (4%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000000480.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000000527.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (5%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000000553.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000000586.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (5%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000000589.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000000608.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (6%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000000778.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000000858.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (7%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000000904.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000000912.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (8%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000001036.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000001089.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (8%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000001193.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000001200.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (9%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000001201.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000001203.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (10%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000001206.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000001213.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (10%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000001214.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000001221.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (11%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000001227.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000001252.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (12%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000001266.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000001339.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (13%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000001370.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000001377.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (13%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000001573.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000001584.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (14%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000001619.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000001645.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (15%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000001690.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000001704.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (16%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000001721.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000001954.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (16%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000001961.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000001997.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (17%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000002011.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000002023.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (18%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000002028.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000002167.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (18%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000002329.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000002409.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (19%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000002410.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000002411.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (20%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000002571.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000002959.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (21%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000003147.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000003178.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (21%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000003198.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000003362.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (22%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000003510.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000003578.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (23%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000003916.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000004022.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (24%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000004084.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000004085.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (24%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000004223.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000004226.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (25%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000004262.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000004776.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (26%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000004993.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000004995.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (27%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000005219.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000005254.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (27%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000005418.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000005574.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (28%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000005810.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000005952.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (29%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000005956.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000005989.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (29%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000005995.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000006365.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (30%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000006534.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000006548.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (31%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000006550.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000006754.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (32%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000006863.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000006874.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (32%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000006934.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000006979.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (33%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000007153.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000007387.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (34%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000007438.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000008529.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (35%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000008638.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000008665.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (35%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000008861.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000008985.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (36%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000026294.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000030707.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (37%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000031364.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000033794.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (37%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000034150.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000036519.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (38%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000042738.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000044665.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (39%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000048304.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000048780.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (40%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000053464.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000053972.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (40%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000053996.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000054771.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (41%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000056145.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000057528.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (42%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000058559.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000059369.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (43%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000060040.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000064030.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (43%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000064957.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000064983.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (44%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000065514.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000065682.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (45%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000068157.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000069275.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (45%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000069526.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000072731.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (46%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000073808.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000074851.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (47%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000076175.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000078772.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (48%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000079132.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000079695.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (48%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000080363.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000080846.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (49%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000081520.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000081932.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (50%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000084601.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000085414.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (51%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000086644.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000087520.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (51%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000088140.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000089904.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (52%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000090522.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000091630.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (53%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000091974.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000091978.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (54%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000092507.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000093242.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (54%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000093363.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000093838.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (55%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000094405.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000094985.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (56%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000095875.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000096432.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (56%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000096691.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000097188.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (57%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000097304.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000097752.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (58%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000099114.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000101895.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (59%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000102088.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000102686.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (59%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000103249.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000103688.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (60%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000104913.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000105355.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (61%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000105504.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000105653.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (62%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000106491.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000106841.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (62%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000107462.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000109487.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (63%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000109578.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000109848.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (64%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000110102.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000110501.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (64%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000110826.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000111364.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (65%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000111743.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000111759.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (66%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000111781.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000112370.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (67%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000112552.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000113573.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (67%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000114180.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000114713.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (68%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000114795.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000114935.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (69%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000115149.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000115210.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (70%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000116397.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000116668.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (70%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000116797.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000116887.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (71%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000116977.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000117895.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (72%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000118328.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000119145.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (72%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000122882.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000122890.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (73%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000122892.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000122900.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (74%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000122904.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000122912.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (75%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000122914.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000122920.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (75%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000128360.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000129937.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (76%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000130634.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000130956.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (77%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000131714.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000133195.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (78%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000134130.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000135530.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (78%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000138036.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000139385.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (79%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000139642.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000139644.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (80%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000142032.json' ...
# ...
# - JSON data loaded successfully!
# - Loading aggregated features (89%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000173161.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000174585.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (89%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000175199.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000175303.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (90%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000175585.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000176937.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (91%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000177497.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000177593.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (91%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000183011.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000184069.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (92%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000185029.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000186631.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (93%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000188301.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000189333.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (94%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000191483.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000192381.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (94%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000192385.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000192541.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (95%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000193958.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000194396.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (96%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000195163.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000197203.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (97%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000200300.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000200540.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (97%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000200818.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000201340.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (98%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000203519.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000204698.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (99%) ...
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000206857.json' ...
# - JSON data loaded successfully!
# - Loading JSON data from the given URL 'https://huggingface.co/datasets/alitourani/Popcorn_Dataset/raw/main/movie_trailers_agg/vgg19/0000207830.json' ...
# - JSON data loaded successfully!
# - Loading aggregated features (100%) ...
# - Creating multimodal DataFrame from unimodal DataFrames ...
# - [Warn] Modality 'audio' not found in input dictionary. Proceeding with available modalities ...
# - Found 121 common items across modalities ...
# - Created a Fused DataFrame ((121, 3)) with modalities: ['text', 'visual'] ...
#   item_id                                               text  \
# 0    5952  [-0.0061330223, -0.043979675, -0.038198307, -0...
# 1  122882  [-0.023205638, -0.031307165, 0.027243624, -0.0...
# 2    1377  [-0.015128693, -0.043594185, -0.022257864, -0....
#
#                                               visual
# 0  [2.841761, 3.125486, 5.015338, 1.566051, 7.108...
# 1  [5.317875, 4.671587, 2.984978, 1.543924, 9.316...
# 2  [2.778624, 8.728314, 0.92988, 1.250507, 2.6093...
# - Final fused DataFrame has 121 items after combining all modalities ...
#
# - Assembling (concatenating) modalities ...
# - Applying CCA with components '40' ...
# - Applied CCA-40 and generated dimensions 40!
# - Applying PCA with variance ratio '0.8' ...
# - Applied PCA-80 and generated dimensions 5632!
# - Modalities assembled successfully!
# - Training set size: (62273, 4), Testing set size: (15537, 4)
# - Available modalities: ['concat', 'cca_40', 'pca_80']
# - Preparing GridSearch procedure ...
# - Training and validation sets prepared!
# - Preparing parameter grid for optimizers (prototype='True', epochs=1) ...
# - Starting HPO ...
# - Starting GridSearch procedure (seed: 42, useGPU: False, parallelHPO: True)...
# -- HPO 'VBPR' in scenario 'text' with 5 param sets...
# Epoch 1/1:   0%|          | 0/499 [00:00<?, ?it/s]
# Epoch 1/1:   0%|          | 0/499 [00:00<?, ?it/s]
# Epoch 1/1:   0%|          | 0/499 [00:00<?, ?it/s]
# Epoch 1/1:   0%|          | 0/499 [00:00<?, ?it/s]
# Epoch 1/1:   0%|          | 0/499 [00:00<?, ?it/s]
# Optimization finished!
# -- Fitting '{'k': 32, 'k2': 8, 'learning_rate': 0.001, 'lambda_w': 0.01, 'lambda_b': 0.01, 'n_epochs': 1}' to get 0.6420 ...
# Optimization finished!
# -- Fitting '{'k': 32, 'k2': 16, 'learning_rate': 0.001, 'lambda_w': 0.01, 'lambda_b': 0.01, 'n_epochs': 1}' to get 0.5554 ...
# Optimization finished!
# -- Fitting '{'k': 64, 'k2': 16, 'learning_rate': 0.001, 'lambda_w': 0.01, 'lambda_b': 0.01, 'n_epochs': 1}' to get 0.5554 ...
# Optimization finished!
# -- Fitting '{'k': 64, 'k2': 8, 'learning_rate': 0.001, 'lambda_w': 0.01, 'lambda_b': 0.01, 'n_epochs': 1}' to get 0.5520 ...
# Optimization finished!
# -- Fitting '{'k': 128, 'k2': 8, 'learning_rate': 0.001, 'lambda_w': 0.01, 'lambda_b': 0.01, 'n_epochs': 1}' to get 0.6420 ...
# -- Found the best case: 'VBPR' in 'text', item '{'k': 32, 'k2': 8, 'learning_rate': 0.001, 'lambda_w': 0.01, 'lambda_b': 0.01, 'n_epochs': 1}' (0.6420), done in 44.6s.
# - Starting GridSearch procedure (seed: 42, useGPU: False, parallelHPO: True)...
# -- HPO 'VBPR' in scenario 'visual' with 5 param sets...
# Epoch 1/1:   0%|          | 0/499 [00:00<?, ?it/s]
# Epoch 1/1:   0%|          | 0/499 [00:00<?, ?it/s]
# Epoch 1/1:   0%|          | 0/499 [00:00<?, ?it/s]
# Epoch 1/1:   0%|          | 0/499 [00:00<?, ?it/s]
# Epoch 1/1:   0%|          | 0/499 [00:00<?, ?it/s]
# Optimization finished!
# -- Fitting '{'k': 32, 'k2': 8, 'learning_rate': 0.001, 'lambda_w': 0.01, 'lambda_b': 0.01, 'n_epochs': 1}' to get 0.5023 ...
# Optimization finished!
# -- Fitting '{'k': 32, 'k2': 16, 'learning_rate': 0.001, 'lambda_w': 0.01, 'lambda_b': 0.01, 'n_epochs': 1}' to get 0.2407 ...
# Optimization finished!
# -- Fitting '{'k': 64, 'k2': 16, 'learning_rate': 0.001, 'lambda_w': 0.01, 'lambda_b': 0.01, 'n_epochs': 1}' to get 0.5180 ...
# Optimization finished!
# -- Fitting '{'k': 64, 'k2': 8, 'learning_rate': 0.001, 'lambda_w': 0.01, 'lambda_b': 0.01, 'n_epochs': 1}' to get 0.4947 ...
# Optimization finished!
# -- Fitting '{'k': 128, 'k2': 8, 'learning_rate': 0.001, 'lambda_w': 0.01, 'lambda_b': 0.01, 'n_epochs': 1}' to get 0.6516 ...
# -- Found the best case: 'VBPR' in 'visual', item '{'k': 128, 'k2': 8, 'learning_rate': 0.001, 'lambda_w': 0.01, 'lambda_b': 0.01, 'n_epochs': 1}' (0.6516), done in 40.4s.
# - Starting GridSearch procedure (seed: 42, useGPU: False, parallelHPO: True)...
# -- HPO 'VBPR' in scenario 'cca_40' with 5 param sets...
# Epoch 1/1:   0%|          | 0/499 [00:00<?, ?it/s]
# Epoch 1/1:   0%|          | 0/499 [00:00<?, ?it/s]
# Epoch 1/1:   0%|          | 0/499 [00:00<?, ?it/s]
# Epoch 1/1:   0%|          | 0/499 [00:00<?, ?it/s]
# Epoch 1/1:   0%|          | 0/499 [00:00<?, ?it/s]
# Optimization finished!
# -- Fitting '{'k': 32, 'k2': 8, 'learning_rate': 0.001, 'lambda_w': 0.01, 'lambda_b': 0.01, 'n_epochs': 1}' to get 0.2840 ...
# Optimization finished!
# -- Fitting '{'k': 32, 'k2': 16, 'learning_rate': 0.001, 'lambda_w': 0.01, 'lambda_b': 0.01, 'n_epochs': 1}' to get 0.5252 ...
# Optimization finished!
# -- Fitting '{'k': 64, 'k2': 8, 'learning_rate': 0.001, 'lambda_w': 0.01, 'lambda_b': 0.01, 'n_epochs': 1}' to get 0.5023 ...
# Optimization finished!
# -- Fitting '{'k': 64, 'k2': 16, 'learning_rate': 0.001, 'lambda_w': 0.01, 'lambda_b': 0.01, 'n_epochs': 1}' to get 0.5554 ...
# Optimization finished!
# -- Fitting '{'k': 128, 'k2': 8, 'learning_rate': 0.001, 'lambda_w': 0.01, 'lambda_b': 0.01, 'n_epochs': 1}' to get 0.2502 ...
# -- Found the best case: 'VBPR' in 'cca_40', item '{'k': 64, 'k2': 16, 'learning_rate': 0.001, 'lambda_w': 0.01, 'lambda_b': 0.01, 'n_epochs': 1}' (0.5554), done in 30.0s.
# - Starting GridSearch procedure (seed: 42, useGPU: False, parallelHPO: True)...
# -- HPO 'VBPR' in scenario 'pca_80' with 5 param sets...
# Epoch 1/1:   0%|          | 0/499 [00:00<?, ?it/s]
# Epoch 1/1:   0%|          | 0/499 [00:00<?, ?it/s]
# Epoch 1/1:   0%|          | 0/499 [00:00<?, ?it/s]
# Epoch 1/1:   0%|          | 0/499 [00:00<?, ?it/s]
# Epoch 1/1:   0%|          | 0/499 [00:00<?, ?it/s]
# Optimization finished!
# -- Fitting '{'k': 32, 'k2': 16, 'learning_rate': 0.001, 'lambda_w': 0.01, 'lambda_b': 0.01, 'n_epochs': 1}' to get 0.2407 ...
# Optimization finished!
# -- Fitting '{'k': 32, 'k2': 8, 'learning_rate': 0.001, 'lambda_w': 0.01, 'lambda_b': 0.01, 'n_epochs': 1}' to get 0.5213 ...
# Optimization finished!
# -- Fitting '{'k': 64, 'k2': 8, 'learning_rate': 0.001, 'lambda_w': 0.01, 'lambda_b': 0.01, 'n_epochs': 1}' to get 0.2574 ...
# Optimization finished!
# -- Fitting '{'k': 64, 'k2': 16, 'learning_rate': 0.001, 'lambda_w': 0.01, 'lambda_b': 0.01, 'n_epochs': 1}' to get 0.3147 ...
# Optimization finished!
# -- Fitting '{'k': 128, 'k2': 8, 'learning_rate': 0.001, 'lambda_w': 0.01, 'lambda_b': 0.01, 'n_epochs': 1}' to get 0.2345 ...
# -- Found the best case: 'VBPR' in 'pca_80', item '{'k': 32, 'k2': 8, 'learning_rate': 0.001, 'lambda_w': 0.01, 'lambda_b': 0.01, 'n_epochs': 1}' (0.5213), done in 27.2s.
# - HPO done! Kept 4 configs.
# Epoch 1/1:   0%|          | 0/623 [00:00<?, ?it/s]
# Optimization finished!
# Epoch 1/1:   0%|          | 0/623 [00:00<?, ?it/s]
# Optimization finished!
# Epoch 1/1:   0%|          | 0/623 [00:00<?, ?it/s]
# Optimization finished!
# Epoch 1/1:   0%|          | 0/623 [00:00<?, ?it/s]
# Optimization finished!
# - Re-fit finished for 'VBPR' with variant 'pca_80'.
# - Grid search done! Kept 4 final models.
#
# ✔ Grid search completed successfully!
# - Final models after HPO: [('VBPR', 'text'), ('VBPR', 'visual'), ('VBPR', 'cca_40'), ('VBPR', 'pca_80')]
# - Generating recommendation lists ...
# - Recommendation lists saved have been saved in 'output_pca08_plmb001_cca40_clmb001/reclist_ml1m_vbpr_openai_raw_top2.csv'! Samples:
#    user_id                                              train  \
# 0        1                  [608, 1193, 1961, 2028, 527, 150]
# 1        2  [480, 1954, 356, 165, 1193, 2571, 2028, 589, 1...
# 2        3                                       [1961, 2167]
#
#                    gt rec_VBPR_text  CR_VBPR_text  ND_VBPR_text  CB_VBPR_text  \
# 0              [1721]    [589, 318]           0.0           0.0      5.115571
# 1  [1690, 3147, 3578]    [858, 608]           0.0           0.0      5.576981
# 2         [480, 1266]   [2028, 589]           0.0           0.0      9.442518
#
#    RC_VBPR_text  HR_VBPR_text  NO_VBPR_text  ...  NO_VBPR_pca_80  \
# 0           0.0             0     12.509528  ...       12.509528
# 1           0.0             0     12.509528  ...       12.509528
# 2           0.0             0     12.509528  ...       12.509528
#
#    FA_VBPR_pca_80  DI_VBPR_pca_80  PR_VBPR_pca_80  AP_VBPR_pca_80  \
# 0             1.0        1.000000             0.0             0.0
# 1             1.0        0.750000             0.0             0.0
# 2             1.0        0.666667             0.0             0.0
#
#   PB_VBPR_pca_80  CV_VBPR_text  CV_VBPR_visual  CV_VBPR_cca_40  CV_VBPR_pca_80
# 0            0.0      0.389831        0.457627        0.440678        0.525424
# 1            0.0      0.389831        0.457627        0.440678        0.525424
# 2            0.0      0.389831        0.457627        0.440678        0.525424
#
# [3 rows x 55 columns]
# - Recommendation lists saved have been saved in 'output_pca08_plmb001_cca40_clmb001/metrics_ml1m_vbpr_openai_raw_top2.csv'! Samples:
# model scenario   NDCG@2  Novelty  Recall@2  Fairness  Diversity  Coverage@2  ColdRate@2  PopularityBias  CalibrationBias  HitRate  Precision      MAP
#  VBPR   cca_40    0.152   12.301     0.125     0.999      0.645       0.441       0.000           0.000            8.955    0.469      0.235    0.104
#  VBPR   pca_80    0.153   12.253     0.129     0.995      0.767       0.525       0.000           0.002            8.613    0.461      0.231    0.106
#  VBPR     text    0.171   12.266     0.143     0.996      0.712       0.390       0.000           0.002            6.721    0.518      0.259    0.119
#  VBPR   visual    0.148   12.306     0.124     1.000      0.665       0.458       0.000           0.000            7.529    0.451      0.226    0.102
