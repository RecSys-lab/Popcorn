# %% [markdown]
# <a href="https://colab.research.google.com/github/RecSys-lab/Popcorn/blob/main/examples/colab/modality_data_fusion_text_visual.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **🍿 Popcorn Framework in Google Colab**
# ### **Modality Fusion (Text and Visual)**
#
# 🎬 Popcorn Framework: [link](https://github.com/RecSys-lab/Popcorn)

# %% [markdown]
# ## **[Step 1] Clone Popcorn Movie Recommender Tool**
#
# Clone the framework into your `GDrive` and prepare it for experiments.
#
# ⚠️ You might see a *"Restart Session"* warning during the first run in Google Colab due to library version mismatches. This is expected! Accept the restart, re-run this cell, and continue!

# %%
# Clone the repo
# !git clone https://github.com/RecSys-lab/Popcorn.git

# Install the required library
# %cd Popcorn
# !pip install -e .

# Add the repository to the Python path
import sys
sys.path.append('/content/Popcorn')

# Go back to the root
# %cd ..
# Out:
# fatal: destination path 'Popcorn' already exists and is not an empty directory.
# /content/Popcorn
# Obtaining file:///content/Popcorn
#   Preparing metadata (setup.py) ... done
# ...
#   Attempting uninstall: Popcorn
#     Found existing installation: Popcorn 1.6.0
#     Uninstalling Popcorn-1.6.0:
#       Successfully uninstalled Popcorn-1.6.0
#   Running setup.py develop for Popcorn
# ...
# /content

# %% [markdown]
# ## 🚀 **[Step 2] Use the Framework**

# %% [markdown]
# ### *1. Load Configurations and Imports*

# %%
import os
import json
import pandas as pd
from popcorn.utils import readConfigs

# Start the Framework
print("Welcome to 'Popcorn' 🍿! Starting the framework for your movie recommendation ...\n")

# Read the configuration file
configs = readConfigs("Popcorn/popcorn/config/config.yml")
# If properly read, print the configurations
if not configs:
    print("Error reading the configuration file!")
# Out:
# Welcome to 'Popcorn' 🍿! Starting the framework for your movie recommendation ...
#
# - Reading the framework's configuration file ...
# - Configuration file loaded successfully!

# %% [markdown]
# ### *2. Fuse Poison-RAG-Plus (Text) and MMTF-14K (Visual) Datasets*

# %%
from popcorn.modalities.fuse_visual_text import (
    fuseTextualVisual_PoisonRag_MMTF14K
)

# Override configs
configs["modalities"]["output_path"] = "/content/Output"

fusedDF = fuseTextualVisual_PoisonRag_MMTF14K(configs)
if fusedDF is None:
    print("- [Error] Fusion failed!")

print(f"- Fused CSV files are saved in '/content/Output'")
# Out:
# - Outputs will be saved in '/content/Output' ...
# - Loading 'Poison-RAG-Plus' textual data for LLM variant 'openai' (augmented=True) ...
#
# - Preparing the 'Poison-RAG-Plus' dataset with 'openai'-driven enriched embeddings ...
# -- Loading data from 'openai_enriched_description_part1.csv.gz' ...
# -- Loading data from 'openai_enriched_description_part2.csv.gz' ...
# -- Loading data from 'openai_enriched_description_part3.csv.gz' ...
# -- Loading data from 'openai_enriched_description_part4.csv.gz' ...
# - Finished loading 3 parts of textual enriched data with 1,606 items!
# - Loading 'Poison-RAG-Plus' textual data for LLM variant 'st' (augmented=True) ...
#
# - Preparing the 'Poison-RAG-Plus' dataset with 'st'-driven enriched embeddings ...
# -- Loading data from 'st_enriched_description_part1.csv.gz' ...
# -- Loading data from 'st_enriched_description_part2.csv.gz' ...
# - Finished loading 1 parts of textual enriched data with 1,606 items!
# ...

# %%
print(fusedDF.keys)
# Out:
# <built-in method keys of dict object at 0x7faf6dc75200>

# %% [markdown]
# ### *3. Fuse Poison-RAG-Plus (Text) and Popcorn (Visual) Datasets*

# %%
from popcorn.modalities.fuse_visual_text import (
    fuseTextualVisual_PoisonRag_Popcorn
)

# Override configs
configs["modalities"]["output_path"] = "/content/Output"

fusedDF = fuseTextualVisual_PoisonRag_Popcorn(configs)
if fusedDF is None:
    print("- [Error] Fusion failed!")

print(f"- Fused CSV files are saved in '/content/Output'")
# Out:
# - Loading 'Poison-RAG-Plus' textual data for LLM variant 'openai' (augmented=True) ...
#
# - Preparing the 'Poison-RAG-Plus' dataset with 'openai'-driven enriched embeddings ...
# -- Loading data from 'openai_enriched_description_part1.csv.gz' ...
# -- Loading data from 'openai_enriched_description_part2.csv.gz' ...
# -- Loading data from 'openai_enriched_description_part3.csv.gz' ...
# -- Loading data from 'openai_enriched_description_part4.csv.gz' ...
# - Finished loading 3 parts of textual enriched data with 1,606 items!
# - Loading 'Poison-RAG-Plus' textual data for LLM variant 'st' (augmented=True) ...
#
# - Preparing the 'Poison-RAG-Plus' dataset with 'st'-driven enriched embeddings ...
# -- Loading data from 'st_enriched_description_part1.csv.gz' ...
# -- Loading data from 'st_enriched_description_part2.csv.gz' ...
# - Finished loading 1 parts of textual enriched data with 1,606 items!
# - Loading 'Poison-RAG-Plus' textual data for LLM variant 'llama' (augmented=True) ...
#
# ...
